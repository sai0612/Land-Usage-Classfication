# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import os

from skimage.io import imread, imsave

from keras import applications
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras import Model

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %matplotlib inline
# Out:
# /home/csci8523/ganta016/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
source_dir = os.path.join('UCMerced_LandUse', 'UCMerced_LandUse', 'Images')

# %%
plt.imshow(imread('UCMerced_LandUse/UCMerced_LandUse/Images/beach/beach01.tif'))
plt.axis('off')
plt.show()

# %%
labels = os.listdir(source_dir)

# %%
pretrained_model = applications.InceptionV3(include_top=False, weights='imagenet')
pretrained_model.trainable = False

# %%
image_data_generator = ImageDataGenerator(rescale=1/255.0)
image_generator = image_data_generator.flow_from_directory(source_dir,
                                                        batch_size=64,
                                                        shuffle=False
                                                        )
count = 0
X_batches, Y_batches = [], []
for X, Y in image_generator:
    X_batches.append(X)
    Y_batches.append(Y)
    count += X.shape[0]
    if count >= image_generator.n:
        break

x_data = np.concatenate(X_batches)
y_data = np.concatenate(Y_batches)
# Out:
# Found 2100 images belonging to 21 classes.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size = 0.4, random_state=101)
x_test, x_val, y_test, y_val = train_test_split(x_val, y_val, test_size = 0.5, random_state=101)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1260, 256, 256, 3)
# (1260, 21)

# %%
inputs = pretrained_model.input
pooling_layer = GlobalAveragePooling2D()(pretrained_model.output)
drop_layer = Dropout(0.20)(pooling_layer)
x_layer = Dense(256, activation='relu')(drop_layer)
drop_layer1 = Dropout(0.5)(x_layer)
outputs = Dense(len(labels), activation='softmax')(drop_layer1)

model = Model(inputs=inputs, outputs=outputs)

# %%
adam = Adam(lr=0.001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(x_train, y_train, batch_size=64, epochs=50, verbose=2, validation_data=(x_val, y_val))
# Out:
# /home/csci8523/ganta016/.local/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/50
# 20/20 - 22s - loss: 2.3634 - accuracy: 0.3159 - val_loss: 1.1808 - val_accuracy: 0.7333 - 22s/epoch - 1s/step
# Epoch 2/50
# 20/20 - 18s - loss: 1.0948 - accuracy: 0.6730 - val_loss: 0.6683 - val_accuracy: 0.8214 - 18s/epoch - 913ms/step
# Epoch 3/50
# 20/20 - 19s - loss: 0.6584 - accuracy: 0.8127 - val_loss: 0.4895 - val_accuracy: 0.8452 - 19s/epoch - 927ms/step
# Epoch 4/50
# 20/20 - 19s - loss: 0.5084 - accuracy: 0.8476 - val_loss: 0.4074 - val_accuracy: 0.8786 - 19s/epoch - 946ms/step
# Epoch 5/50
# 20/20 - 19s - loss: 0.4385 - accuracy: 0.8611 - val_loss: 0.3874 - val_accuracy: 0.8833 - 19s/epoch - 950ms/step
# Epoch 6/50
# 20/20 - 19s - loss: 0.3393 - accuracy: 0.8937 - val_loss: 0.3537 - val_accuracy: 0.9000 - 19s/epoch - 961ms/step
# Epoch 7/50
# 20/20 - 19s - loss: 0.2827 - accuracy: 0.9222 - val_loss: 0.3328 - val_accuracy: 0.8905 - 19s/epoch - 945ms/step
# Epoch 8/50
# 20/20 - 19s - loss: 0.2337 - accuracy: 0.9294 - val_loss: 0.3502 - val_accuracy: 0.9095 - 19s/epoch - 951ms/step
# Epoch 9/50
# 20/20 - 19s - loss: 0.2041 - accuracy: 0.9413 - val_loss: 0.3272 - val_accuracy: 0.9071 - 19s/epoch - 959ms/step
# Epoch 10/50
# 20/20 - 19s - loss: 0.1659 - accuracy: 0.9579 - val_loss: 0.3207 - val_accuracy: 0.9000 - 19s/epoch - 974ms/step
# Epoch 11/50
# 20/20 - 19s - loss: 0.1667 - accuracy: 0.9579 - val_loss: 0.2864 - val_accuracy: 0.9071 - 19s/epoch - 963ms/step
# Epoch 12/50
# 20/20 - 19s - loss: 0.1441 - accuracy: 0.9579 - val_loss: 0.3128 - val_accuracy: 0.9167 - 19s/epoch - 965ms/step
# Epoch 13/50
# 20/20 - 19s - loss: 0.1313 - accuracy: 0.9683 - val_loss: 0.2964 - val_accuracy: 0.9190 - 19s/epoch - 973ms/step
# Epoch 14/50
# 20/20 - 19s - loss: 0.1388 - accuracy: 0.9571 - val_loss: 0.3210 - val_accuracy: 0.9143 - 19s/epoch - 960ms/step
# Epoch 15/50
# 20/20 - 19s - loss: 0.1073 - accuracy: 0.9706 - val_loss: 0.3178 - val_accuracy: 0.9095 - 19s/epoch - 963ms/step
# Epoch 16/50
# 20/20 - 19s - loss: 0.0915 - accuracy: 0.9770 - val_loss: 0.3548 - val_accuracy: 0.8976 - 19s/epoch - 974ms/step
# Epoch 17/50
# 20/20 - 20s - loss: 0.0963 - accuracy: 0.9754 - val_loss: 0.3337 - val_accuracy: 0.9095 - 20s/epoch - 1000ms/step
# Epoch 18/50
# 20/20 - 20s - loss: 0.0712 - accuracy: 0.9802 - val_loss: 0.3069 - val_accuracy: 0.9048 - 20s/epoch - 994ms/step
# Epoch 19/50
# 20/20 - 20s - loss: 0.0671 - accuracy: 0.9833 - val_loss: 0.3210 - val_accuracy: 0.9095 - 20s/epoch - 993ms/step
# Epoch 20/50
# 20/20 - 20s - loss: 0.0657 - accuracy: 0.9817 - val_loss: 0.3095 - val_accuracy: 0.9167 - 20s/epoch - 987ms/step
# Epoch 21/50
# 20/20 - 20s - loss: 0.0581 - accuracy: 0.9841 - val_loss: 0.3214 - val_accuracy: 0.9143 - 20s/epoch - 978ms/step
# Epoch 22/50
# 20/20 - 20s - loss: 0.0558 - accuracy: 0.9921 - val_loss: 0.3439 - val_accuracy: 0.9071 - 20s/epoch - 989ms/step
# Epoch 23/50
# 20/20 - 20s - loss: 0.0572 - accuracy: 0.9849 - val_loss: 0.3036 - val_accuracy: 0.9190 - 20s/epoch - 989ms/step
# Epoch 24/50
# 20/20 - 20s - loss: 0.0509 - accuracy: 0.9889 - val_loss: 0.3087 - val_accuracy: 0.9167 - 20s/epoch - 987ms/step
# Epoch 25/50
# 20/20 - 20s - loss: 0.0561 - accuracy: 0.9865 - val_loss: 0.3009 - val_accuracy: 0.9190 - 20s/epoch - 986ms/step
# Epoch 26/50
# 20/20 - 20s - loss: 0.0477 - accuracy: 0.9905 - val_loss: 0.2973 - val_accuracy: 0.9190 - 20s/epoch - 992ms/step
# Epoch 27/50
# 20/20 - 20s - loss: 0.0361 - accuracy: 0.9952 - val_loss: 0.3077 - val_accuracy: 0.9167 - 20s/epoch - 986ms/step
# Epoch 28/50
# 20/20 - 20s - loss: 0.0435 - accuracy: 0.9881 - val_loss: 0.3121 - val_accuracy: 0.9119 - 20s/epoch - 993ms/step
# Epoch 29/50
# 20/20 - 20s - loss: 0.0425 - accuracy: 0.9905 - val_loss: 0.3168 - val_accuracy: 0.9048 - 20s/epoch - 999ms/step
# Epoch 30/50
# 20/20 - 20s - loss: 0.0421 - accuracy: 0.9905 - val_loss: 0.3277 - val_accuracy: 0.9119 - 20s/epoch - 1s/step
# Epoch 31/50
# 20/20 - 20s - loss: 0.0361 - accuracy: 0.9968 - val_loss: 0.3103 - val_accuracy: 0.9071 - 20s/epoch - 998ms/step
# Epoch 32/50
# 20/20 - 20s - loss: 0.0366 - accuracy: 0.9905 - val_loss: 0.3216 - val_accuracy: 0.9214 - 20s/epoch - 993ms/step
# Epoch 33/50
# 20/20 - 20s - loss: 0.0316 - accuracy: 0.9952 - val_loss: 0.3331 - val_accuracy: 0.9214 - 20s/epoch - 1000ms/step
# Epoch 34/50
# 20/20 - 20s - loss: 0.0353 - accuracy: 0.9897 - val_loss: 0.3061 - val_accuracy: 0.9238 - 20s/epoch - 998ms/step
# Epoch 35/50
# 20/20 - 20s - loss: 0.0349 - accuracy: 0.9921 - val_loss: 0.3125 - val_accuracy: 0.9190 - 20s/epoch - 984ms/step
# Epoch 36/50
# 20/20 - 20s - loss: 0.0393 - accuracy: 0.9913 - val_loss: 0.3105 - val_accuracy: 0.9190 - 20s/epoch - 981ms/step
# Epoch 37/50
# 20/20 - 20s - loss: 0.0287 - accuracy: 0.9952 - val_loss: 0.3484 - val_accuracy: 0.9095 - 20s/epoch - 999ms/step
# Epoch 38/50
# 20/20 - 20s - loss: 0.0301 - accuracy: 0.9944 - val_loss: 0.3155 - val_accuracy: 0.9238 - 20s/epoch - 981ms/step
# Epoch 39/50
# 20/20 - 20s - loss: 0.0271 - accuracy: 0.9952 - val_loss: 0.3168 - val_accuracy: 0.9214 - 20s/epoch - 975ms/step
# Epoch 40/50
# 20/20 - 20s - loss: 0.0272 - accuracy: 0.9929 - val_loss: 0.3212 - val_accuracy: 0.9190 - 20s/epoch - 998ms/step
# Epoch 41/50
# 20/20 - 20s - loss: 0.0251 - accuracy: 0.9937 - val_loss: 0.3455 - val_accuracy: 0.9095 - 20s/epoch - 996ms/step
# Epoch 42/50
# 20/20 - 20s - loss: 0.0259 - accuracy: 0.9929 - val_loss: 0.3321 - val_accuracy: 0.9238 - 20s/epoch - 987ms/step
# Epoch 43/50
# 20/20 - 20s - loss: 0.0246 - accuracy: 0.9952 - val_loss: 0.3381 - val_accuracy: 0.9238 - 20s/epoch - 1s/step
# Epoch 44/50
# 20/20 - 20s - loss: 0.0320 - accuracy: 0.9889 - val_loss: 0.3553 - val_accuracy: 0.9071 - 20s/epoch - 990ms/step
# Epoch 45/50
# 20/20 - 20s - loss: 0.0277 - accuracy: 0.9960 - val_loss: 0.3463 - val_accuracy: 0.9214 - 20s/epoch - 989ms/step
# Epoch 46/50
# 20/20 - 20s - loss: 0.0236 - accuracy: 0.9944 - val_loss: 0.3360 - val_accuracy: 0.9167 - 20s/epoch - 978ms/step
# Epoch 47/50
# 20/20 - 20s - loss: 0.0368 - accuracy: 0.9913 - val_loss: 0.3528 - val_accuracy: 0.9071 - 20s/epoch - 983ms/step
# Epoch 48/50
# 20/20 - 20s - loss: 0.0293 - accuracy: 0.9944 - val_loss: 0.3531 - val_accuracy: 0.9048 - 20s/epoch - 1000ms/step
# Epoch 49/50
# 20/20 - 20s - loss: 0.0244 - accuracy: 0.9944 - val_loss: 0.3591 - val_accuracy: 0.9167 - 20s/epoch - 1s/step
# Epoch 50/50
# 20/20 - 20s - loss: 0.0209 - accuracy: 0.9968 - val_loss: 0.3191 - val_accuracy: 0.9214 - 20s/epoch - 1s/step

# %%
model.save_weights("model_dense_pre.h5")

# %%
for layer in pretrained_model.layers[:249]:
   layer.trainable = False
for layer in pretrained_model.layers[249:]:
   layer.trainable = True

inputs = pretrained_model.input
pooling_layer = GlobalAveragePooling2D()(pretrained_model.output)
drop_layer = Dropout(0.20)(pooling_layer)
x_layer = Dense(256, activation='relu')(drop_layer)
drop_layer1 = Dropout(0.5)(x_layer)
outputs = Dense(len(labels), activation='softmax')(drop_layer1)

model = Model(inputs=inputs, outputs=outputs)
model.load_weights("model_dense_pre.h5")
adam = Adam()
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=100, verbose=2, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 20/20 - 31s - loss: 0.5260 - accuracy: 0.8563 - val_loss: 3.1538 - val_accuracy: 0.6762 - 31s/epoch - 2s/step
# Epoch 2/100
# 20/20 - 26s - loss: 0.1456 - accuracy: 0.9667 - val_loss: 1.6432 - val_accuracy: 0.8262 - 26s/epoch - 1s/step
# Epoch 3/100
# 20/20 - 26s - loss: 0.0356 - accuracy: 0.9921 - val_loss: 1.1754 - val_accuracy: 0.8548 - 26s/epoch - 1s/step
# Epoch 4/100
# 20/20 - 26s - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.7937 - val_accuracy: 0.9024 - 26s/epoch - 1s/step
# Epoch 5/100
# 20/20 - 26s - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.5037 - val_accuracy: 0.9286 - 26s/epoch - 1s/step
# Epoch 6/100
# 20/20 - 26s - loss: 0.0162 - accuracy: 0.9960 - val_loss: 0.5209 - val_accuracy: 0.9381 - 26s/epoch - 1s/step
# Epoch 7/100
# 20/20 - 26s - loss: 0.0423 - accuracy: 0.9873 - val_loss: 0.6093 - val_accuracy: 0.9333 - 26s/epoch - 1s/step
# Epoch 8/100
# 20/20 - 27s - loss: 0.0672 - accuracy: 0.9881 - val_loss: 1.0727 - val_accuracy: 0.8881 - 27s/epoch - 1s/step
# Epoch 9/100
# 20/20 - 27s - loss: 0.0242 - accuracy: 0.9952 - val_loss: 1.3172 - val_accuracy: 0.8690 - 27s/epoch - 1s/step
# Epoch 10/100
# 20/20 - 27s - loss: 0.0255 - accuracy: 0.9944 - val_loss: 0.5762 - val_accuracy: 0.9333 - 27s/epoch - 1s/step
# Epoch 11/100
# 20/20 - 27s - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.4247 - val_accuracy: 0.9310 - 27s/epoch - 1s/step
# Epoch 12/100
# 20/20 - 27s - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.5084 - val_accuracy: 0.9429 - 27s/epoch - 1s/step
# Epoch 13/100
# 20/20 - 27s - loss: 0.0184 - accuracy: 0.9929 - val_loss: 0.6460 - val_accuracy: 0.9238 - 27s/epoch - 1s/step
# Epoch 14/100
# 20/20 - 28s - loss: 0.0600 - accuracy: 0.9857 - val_loss: 0.3598 - val_accuracy: 0.9381 - 28s/epoch - 1s/step
# Epoch 15/100
# 20/20 - 28s - loss: 0.0191 - accuracy: 0.9952 - val_loss: 0.4824 - val_accuracy: 0.9214 - 28s/epoch - 1s/step
# Epoch 16/100
# 20/20 - 28s - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.3354 - val_accuracy: 0.9476 - 28s/epoch - 1s/step
# Epoch 17/100
# 20/20 - 27s - loss: 0.0145 - accuracy: 0.9984 - val_loss: 0.6000 - val_accuracy: 0.9238 - 27s/epoch - 1s/step
# Epoch 18/100
# 20/20 - 26s - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.5904 - val_accuracy: 0.9262 - 26s/epoch - 1s/step
# Epoch 19/100
# 20/20 - 26s - loss: 0.0198 - accuracy: 0.9960 - val_loss: 0.6603 - val_accuracy: 0.9262 - 26s/epoch - 1s/step
# Epoch 20/100
# 20/20 - 27s - loss: 0.0113 - accuracy: 0.9976 - val_loss: 0.7073 - val_accuracy: 0.9071 - 27s/epoch - 1s/step
# Epoch 21/100
# 20/20 - 27s - loss: 0.0317 - accuracy: 0.9937 - val_loss: 1.8393 - val_accuracy: 0.8214 - 27s/epoch - 1s/step
# Epoch 22/100
# 20/20 - 27s - loss: 0.0700 - accuracy: 0.9913 - val_loss: 2.1280 - val_accuracy: 0.8333 - 27s/epoch - 1s/step
# Epoch 23/100
# 20/20 - 26s - loss: 0.0386 - accuracy: 0.9921 - val_loss: 2.4897 - val_accuracy: 0.8190 - 26s/epoch - 1s/step
# Epoch 24/100
# 20/20 - 27s - loss: 0.0504 - accuracy: 0.9889 - val_loss: 3.3857 - val_accuracy: 0.8476 - 27s/epoch - 1s/step
# Epoch 25/100
# 20/20 - 27s - loss: 0.1028 - accuracy: 0.9865 - val_loss: 6.1714 - val_accuracy: 0.6000 - 27s/epoch - 1s/step
# Epoch 26/100
# 20/20 - 27s - loss: 0.0235 - accuracy: 0.9921 - val_loss: 1.2595 - val_accuracy: 0.8762 - 27s/epoch - 1s/step
# Epoch 27/100
# 20/20 - 26s - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.7274 - val_accuracy: 0.9143 - 26s/epoch - 1s/step
# Epoch 28/100
# 20/20 - 27s - loss: 0.0215 - accuracy: 0.9929 - val_loss: 0.6343 - val_accuracy: 0.9333 - 27s/epoch - 1s/step
# Epoch 29/100
# 20/20 - 27s - loss: 0.0228 - accuracy: 0.9944 - val_loss: 0.5544 - val_accuracy: 0.9310 - 27s/epoch - 1s/step
# Epoch 30/100
# 20/20 - 27s - loss: 0.0282 - accuracy: 0.9944 - val_loss: 0.4999 - val_accuracy: 0.9452 - 27s/epoch - 1s/step
# Epoch 31/100
# 20/20 - 27s - loss: 0.0153 - accuracy: 0.9944 - val_loss: 0.4613 - val_accuracy: 0.9405 - 27s/epoch - 1s/step
# Epoch 32/100
# 20/20 - 27s - loss: 0.0319 - accuracy: 0.9968 - val_loss: 0.8453 - val_accuracy: 0.9000 - 27s/epoch - 1s/step
# Epoch 33/100
# 20/20 - 27s - loss: 0.0186 - accuracy: 0.9960 - val_loss: 0.6255 - val_accuracy: 0.9262 - 27s/epoch - 1s/step
# Epoch 34/100
# 20/20 - 27s - loss: 0.0137 - accuracy: 0.9976 - val_loss: 0.6365 - val_accuracy: 0.9190 - 27s/epoch - 1s/step
# Epoch 35/100
# 20/20 - 27s - loss: 0.0385 - accuracy: 0.9937 - val_loss: 0.5184 - val_accuracy: 0.9238 - 27s/epoch - 1s/step
# Epoch 36/100
# 20/20 - 27s - loss: 0.0165 - accuracy: 0.9960 - val_loss: 0.4213 - val_accuracy: 0.9333 - 27s/epoch - 1s/step
# Epoch 37/100
# 20/20 - 27s - loss: 0.0118 - accuracy: 0.9976 - val_loss: 0.4133 - val_accuracy: 0.9381 - 27s/epoch - 1s/step
# Epoch 38/100
# 20/20 - 27s - loss: 0.0215 - accuracy: 0.9984 - val_loss: 0.3434 - val_accuracy: 0.9452 - 27s/epoch - 1s/step
# Epoch 39/100
# 20/20 - 27s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2950 - val_accuracy: 0.9571 - 27s/epoch - 1s/step
# Epoch 40/100
# 20/20 - 27s - loss: 0.0089 - accuracy: 0.9992 - val_loss: 0.2942 - val_accuracy: 0.9548 - 27s/epoch - 1s/step
# Epoch 41/100
# 20/20 - 27s - loss: 0.0076 - accuracy: 0.9960 - val_loss: 0.2910 - val_accuracy: 0.9548 - 27s/epoch - 1s/step
# Epoch 42/100
# 20/20 - 27s - loss: 0.0208 - accuracy: 0.9944 - val_loss: 0.6031 - val_accuracy: 0.9262 - 27s/epoch - 1s/step
# Epoch 43/100
# 20/20 - 27s - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.4787 - val_accuracy: 0.9286 - 27s/epoch - 1s/step
# Epoch 44/100
# 20/20 - 27s - loss: 0.0198 - accuracy: 0.9960 - val_loss: 0.2996 - val_accuracy: 0.9429 - 27s/epoch - 1s/step
# Epoch 45/100
# 20/20 - 27s - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.2517 - val_accuracy: 0.9595 - 27s/epoch - 1s/step
# Epoch 46/100
# 20/20 - 27s - loss: 0.0492 - accuracy: 0.9929 - val_loss: 0.6952 - val_accuracy: 0.9357 - 27s/epoch - 1s/step
# Epoch 47/100
# 20/20 - 27s - loss: 0.0232 - accuracy: 0.9944 - val_loss: 1.4949 - val_accuracy: 0.8952 - 27s/epoch - 1s/step
# Epoch 48/100
# 20/20 - 27s - loss: 0.0128 - accuracy: 0.9960 - val_loss: 3.5979 - val_accuracy: 0.8214 - 27s/epoch - 1s/step
# Epoch 49/100
# 20/20 - 27s - loss: 0.0097 - accuracy: 0.9968 - val_loss: 1.5500 - val_accuracy: 0.8429 - 27s/epoch - 1s/step
# Epoch 50/100
# 20/20 - 27s - loss: 0.0109 - accuracy: 0.9968 - val_loss: 1.1814 - val_accuracy: 0.8786 - 27s/epoch - 1s/step
# Epoch 51/100
# 20/20 - 27s - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.9414 - val_accuracy: 0.9000 - 27s/epoch - 1s/step
# Epoch 52/100
# 20/20 - 27s - loss: 0.0112 - accuracy: 0.9976 - val_loss: 3.3890 - val_accuracy: 0.8357 - 27s/epoch - 1s/step
# Epoch 53/100
# 20/20 - 27s - loss: 0.0090 - accuracy: 0.9968 - val_loss: 1.9198 - val_accuracy: 0.8929 - 27s/epoch - 1s/step
# Epoch 54/100
# 20/20 - 27s - loss: 0.0163 - accuracy: 0.9960 - val_loss: 2.0796 - val_accuracy: 0.8476 - 27s/epoch - 1s/step
# Epoch 55/100
# 20/20 - 27s - loss: 0.0414 - accuracy: 0.9897 - val_loss: 1.0220 - val_accuracy: 0.9119 - 27s/epoch - 1s/step
# Epoch 56/100
# 20/20 - 27s - loss: 0.0538 - accuracy: 0.9889 - val_loss: 0.8025 - val_accuracy: 0.9119 - 27s/epoch - 1s/step
# Epoch 57/100
# 20/20 - 27s - loss: 0.0231 - accuracy: 0.9929 - val_loss: 0.8832 - val_accuracy: 0.9071 - 27s/epoch - 1s/step
# Epoch 58/100
# 20/20 - 27s - loss: 0.0135 - accuracy: 0.9960 - val_loss: 1.0686 - val_accuracy: 0.9048 - 27s/epoch - 1s/step
# Epoch 59/100
# 20/20 - 27s - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.9200 - val_accuracy: 0.9167 - 27s/epoch - 1s/step
# Epoch 60/100
# 20/20 - 27s - loss: 0.0163 - accuracy: 0.9944 - val_loss: 0.6873 - val_accuracy: 0.9262 - 27s/epoch - 1s/step
# Epoch 61/100
# 20/20 - 27s - loss: 0.0239 - accuracy: 0.9952 - val_loss: 0.6358 - val_accuracy: 0.9310 - 27s/epoch - 1s/step
# Epoch 62/100
# 20/20 - 27s - loss: 0.0124 - accuracy: 0.9976 - val_loss: 0.6183 - val_accuracy: 0.9286 - 27s/epoch - 1s/step
# Epoch 63/100
# 20/20 - 27s - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.6688 - val_accuracy: 0.9310 - 27s/epoch - 1s/step
# Epoch 64/100
# 20/20 - 27s - loss: 0.0150 - accuracy: 0.9960 - val_loss: 0.5272 - val_accuracy: 0.9381 - 27s/epoch - 1s/step
# Epoch 65/100
# 20/20 - 27s - loss: 0.0168 - accuracy: 0.9960 - val_loss: 0.8771 - val_accuracy: 0.9024 - 27s/epoch - 1s/step
# Epoch 66/100
# 20/20 - 27s - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.7762 - val_accuracy: 0.9214 - 27s/epoch - 1s/step
# Epoch 67/100
# 20/20 - 27s - loss: 0.0038 - accuracy: 0.9976 - val_loss: 0.7039 - val_accuracy: 0.9310 - 27s/epoch - 1s/step
# Epoch 68/100
# 20/20 - 27s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.5916 - val_accuracy: 0.9310 - 27s/epoch - 1s/step
# Epoch 69/100
# 20/20 - 27s - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.7248 - val_accuracy: 0.9143 - 27s/epoch - 1s/step
# Epoch 70/100
# 20/20 - 27s - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.5187 - val_accuracy: 0.9310 - 27s/epoch - 1s/step
# Epoch 71/100
# 20/20 - 27s - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.5156 - val_accuracy: 0.9333 - 27s/epoch - 1s/step
# Epoch 72/100
# 20/20 - 27s - loss: 0.0120 - accuracy: 0.9976 - val_loss: 0.4689 - val_accuracy: 0.9286 - 27s/epoch - 1s/step
# Epoch 73/100
# 20/20 - 27s - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.5458 - val_accuracy: 0.9262 - 27s/epoch - 1s/step
# Epoch 74/100
# 20/20 - 27s - loss: 0.0567 - accuracy: 0.9905 - val_loss: 0.6492 - val_accuracy: 0.9167 - 27s/epoch - 1s/step
# Epoch 75/100
# 20/20 - 27s - loss: 0.0097 - accuracy: 0.9976 - val_loss: 0.9016 - val_accuracy: 0.9000 - 27s/epoch - 1s/step
# Epoch 76/100
# 20/20 - 27s - loss: 0.0058 - accuracy: 0.9976 - val_loss: 0.6614 - val_accuracy: 0.9214 - 27s/epoch - 1s/step
# Epoch 77/100
# 20/20 - 26s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5846 - val_accuracy: 0.9286 - 26s/epoch - 1s/step
# Epoch 78/100
# 20/20 - 27s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 0.9405 - 27s/epoch - 1s/step
# Epoch 79/100
# 20/20 - 27s - loss: 4.2372e-04 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.9405 - 27s/epoch - 1s/step
# Epoch 80/100
# 20/20 - 27s - loss: 8.2981e-04 - accuracy: 1.0000 - val_loss: 0.4747 - val_accuracy: 0.9405 - 27s/epoch - 1s/step
# Epoch 81/100
# 20/20 - 27s - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.4417 - val_accuracy: 0.9405 - 27s/epoch - 1s/step
# Epoch 82/100
# 20/20 - 27s - loss: 9.9512e-04 - accuracy: 1.0000 - val_loss: 0.4464 - val_accuracy: 0.9405 - 27s/epoch - 1s/step
# Epoch 83/100
# 20/20 - 27s - loss: 8.1004e-04 - accuracy: 1.0000 - val_loss: 0.4575 - val_accuracy: 0.9405 - 27s/epoch - 1s/step
# Epoch 84/100
# 20/20 - 27s - loss: 9.8080e-04 - accuracy: 1.0000 - val_loss: 0.4336 - val_accuracy: 0.9452 - 27s/epoch - 1s/step
# Epoch 85/100
# 20/20 - 27s - loss: 3.3472e-04 - accuracy: 1.0000 - val_loss: 0.4201 - val_accuracy: 0.9476 - 27s/epoch - 1s/step
# Epoch 86/100
# 20/20 - 27s - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.3841 - val_accuracy: 0.9524 - 27s/epoch - 1s/step
# Epoch 87/100
# 20/20 - 27s - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.4708 - val_accuracy: 0.9333 - 27s/epoch - 1s/step
# Epoch 88/100
# 20/20 - 25s - loss: 2.7724e-04 - accuracy: 1.0000 - val_loss: 0.4590 - val_accuracy: 0.9381 - 25s/epoch - 1s/step
# Epoch 89/100
# 20/20 - 17s - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.4460 - val_accuracy: 0.9429 - 17s/epoch - 844ms/step
# Epoch 90/100
# 20/20 - 15s - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.4144 - val_accuracy: 0.9524 - 15s/epoch - 765ms/step
# Epoch 91/100
# 20/20 - 15s - loss: 0.0034 - accuracy: 0.9984 - val_loss: 0.5090 - val_accuracy: 0.9429 - 15s/epoch - 749ms/step
# Epoch 92/100
# 20/20 - 15s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4612 - val_accuracy: 0.9452 - 15s/epoch - 748ms/step
# Epoch 93/100
# 20/20 - 15s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8701 - val_accuracy: 0.9238 - 15s/epoch - 745ms/step
# Epoch 94/100
# 20/20 - 15s - loss: 0.0073 - accuracy: 0.9992 - val_loss: 0.4873 - val_accuracy: 0.9357 - 15s/epoch - 742ms/step
# Epoch 95/100
# 20/20 - 15s - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.4092 - val_accuracy: 0.9429 - 15s/epoch - 741ms/step
# Epoch 96/100
# 20/20 - 15s - loss: 3.1431e-04 - accuracy: 1.0000 - val_loss: 0.4022 - val_accuracy: 0.9405 - 15s/epoch - 754ms/step
# Epoch 97/100
# 20/20 - 15s - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.3743 - val_accuracy: 0.9524 - 15s/epoch - 746ms/step
# Epoch 98/100
# 20/20 - 15s - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.3566 - val_accuracy: 0.9619 - 15s/epoch - 745ms/step
# Epoch 99/100
# 20/20 - 15s - loss: 7.4218e-04 - accuracy: 1.0000 - val_loss: 0.3593 - val_accuracy: 0.9548 - 15s/epoch - 744ms/step
# Epoch 100/100
# 20/20 - 15s - loss: 8.9680e-04 - accuracy: 0.9992 - val_loss: 0.4313 - val_accuracy: 0.9548 - 15s/epoch - 745ms/step

# %%
model.save_weights("uc_merced_final_2.h5")

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'r', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
model.load_weights("uc_merced_final_2.h5")

# %%
y_pred = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 14/14 [==============================] - 4s 211ms/step

# %%
y_p = np.zeros((len(y_pred), 21))
j =0
for i in y_pred:
    y_p[j][int(i)]=1
    j = j+1

# %%
y_pred = y_p

# %%
import pandas as pd

total = np.sum(y_test,axis = 0)
tp = np.sum(y_test*y_pred,axis=0)
tn = np.sum((1-y_test)*(1-y_pred),axis=0)
fp = np.sum((1-y_test)*y_pred,axis=0)
fn = np.sum(y_test*(1-y_pred),axis=0)

d = {'Total':total,'TP':tp,'TN':tn,'FP':fp,'FN':fn}
pd.DataFrame(d)
# Out:
#     Total    TP     TN   FP   FN
# 0    20.0  20.0  400.0  0.0  0.0
# 1    23.0  20.0  397.0  0.0  3.0
# 2    17.0  17.0  402.0  1.0  0.0
# 3    16.0  16.0  404.0  0.0  0.0
# 4    19.0  18.0  400.0  1.0  1.0
# 5    18.0  18.0  402.0  0.0  0.0
# 6    12.0  10.0  405.0  3.0  2.0
# 7    24.0  24.0  396.0  0.0  0.0
# 8    22.0  22.0  395.0  3.0  0.0
# 9    24.0  23.0  394.0  2.0  1.0
# 10   22.0  22.0  398.0  0.0  0.0
# 11   16.0  15.0  403.0  1.0  1.0
# 12   17.0  15.0  400.0  3.0  2.0
# 13   23.0  22.0  397.0  0.0  1.0
# 14   16.0  16.0  404.0  0.0  0.0
# 15   28.0  28.0  391.0  1.0  0.0
# 16   26.0  25.0  394.0  0.0  1.0
# 17   19.0  17.0  401.0  0.0  2.0
# 18   17.0  13.0  402.0  1.0  4.0
# 19   21.0  21.0  398.0  1.0  0.0
# 20   20.0  20.0  399.0  1.0  0.0

# %%
sum = np.add(tp, fp)
precision = np.divide(tp, sum)
recall = np.divide(tp, np.add(tp, fn))
accuracy = np.divide(np.add(tp, tn), np.add(fp, np.add(fn, np.add(tp, tn))))
f1 = 2*(np.divide(np.multiply(precision, recall), np.add(precision, recall)))
f2 = (np.divide(5*np.multiply(precision, recall), np.add(4*precision, recall)))
evalution_metrics = {'Accuracy':accuracy,'Precision':precision,'Recall':recall,'f1':f1, 'f2': f2}
pd.DataFrame(evalution_metrics, index = labels)
# Out:
#                    Accuracy  Precision    Recall        f1        f2
# agricultural       1.000000   1.000000  1.000000  1.000000  1.000000
# airplane           0.992857   1.000000  0.869565  0.930233  0.892857
# baseballdiamond    0.997619   0.944444  1.000000  0.971429  0.988372
# beach              1.000000   1.000000  1.000000  1.000000  1.000000
# buildings          0.995238   0.947368  0.947368  0.947368  0.947368
# chaparral          1.000000   1.000000  1.000000  1.000000  1.000000
# denseresidential   0.988095   0.769231  0.833333  0.800000  0.819672
# forest             1.000000   1.000000  1.000000  1.000000  1.000000
# freeway            0.992857   0.880000  1.000000  0.936170  0.973451
# golfcourse         0.992857   0.920000  0.958333  0.938776  0.950413
# harbor             1.000000   1.000000  1.000000  1.000000  1.000000
# intersection       0.995238   0.937500  0.937500  0.937500  0.937500
# mediumresidential  0.988095   0.833333  0.882353  0.857143  0.872093
# mobilehomepark     0.997619   1.000000  0.956522  0.977778  0.964912
# overpass           1.000000   1.000000  1.000000  1.000000  1.000000
# parkinglot         0.997619   0.965517  1.000000  0.982456  0.992908
# river              0.997619   1.000000  0.961538  0.980392  0.968992
# runway             0.995238   1.000000  0.894737  0.944444  0.913978
# sparseresidential  0.988095   0.928571  0.764706  0.838710  0.792683
# storagetanks       0.997619   0.954545  1.000000  0.976744  0.990566
# tenniscourt        0.997619   0.952381  1.000000  0.975610  0.990099

# %%
x = ["agricultural", "airplane", "baseball diamond", "beach", "buildings", "chaparral", "dense residential",
"forest", "freeway", "golf course", "harbor", "intersection", "medium density residential", "mobile home park",
"overpass", "parking lot", "river", "runway", "sparse residential","storage tanks", "tennis courts"]
plt.xticks(rotation = 90)
plt.bar(x,accuracy)
plt.show()

# %%
#y_test = np.nonzero(y_test)[1]
#y_pred = np.nonzero(y_pred)[1]
accuracy = accuracy_score(y_test, y_pred)
print(f'Model predication accuracy: {accuracy:.3f}')
print(f'\nClassification report:\n {classification_report(y_test, y_pred)}')
# Out:
# Model predication accuracy: 0.957
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      0.87      0.93        23
#            2       0.94      1.00      0.97        17
#            3       1.00      1.00      1.00        16
#            4       0.95      0.95      0.95        19
#            5       1.00      1.00      1.00        18
#            6       0.77      0.83      0.80        12
#            7       1.00      1.00      1.00        24
#            8       0.88      1.00      0.94        22
#            9       0.92      0.96      0.94        24
#           10       1.00      1.00      1.00        22
#           11       0.94      0.94      0.94        16
#           12       0.83      0.88      0.86        17
#           13       1.00      0.96      0.98        23
#           14       1.00      1.00      1.00        16
#           15       0.97      1.00      0.98        28
#           16       1.00      0.96      0.98        26
#           17       1.00      0.89      0.94        19
#           18       0.93      0.76      0.84        17
#           19       0.95      1.00      0.98        21
#           20       0.95      1.00      0.98        20
#
#    micro avg       0.96      0.96      0.96       420
#    macro avg       0.95      0.95      0.95       420
# weighted avg       0.96      0.96      0.96       420
#  samples avg       0.96      0.96      0.96       420
