# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import os

from skimage.io import imread, imsave

from keras import applications
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras import Model

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %matplotlib inline
# Out:
# /home/csci8523/attan005/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
source_dir = os.path.join('UCMerced_LandUse', 'UCMerced_LandUse', 'Images')

# %%
plt.imshow(imread('UCMerced_LandUse/UCMerced_LandUse/Images/beach/beach01.tif'))
plt.axis('off')
plt.show()

# %%
labels = os.listdir(source_dir)

# %%
pretrained_model = applications.InceptionV3(include_top=False, weights=None)
pretrained_model.trainable = True

# %%
image_data_generator = ImageDataGenerator(rescale=1/255.0)
image_generator = image_data_generator.flow_from_directory(source_dir,
                                                        batch_size=64,
                                                        shuffle=False
                                                        )
count = 0
X_batches, Y_batches = [], []
for X, Y in image_generator:
    X_batches.append(X)
    Y_batches.append(Y)
    count += X.shape[0]
    if count >= image_generator.n:
        break

x_data = np.concatenate(X_batches)
y_data = np.concatenate(Y_batches)
# Out:
# Found 2100 images belonging to 21 classes.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size = 0.4, random_state=101)
x_test, x_val, y_test, y_val = train_test_split(x_val, y_val, test_size = 0.5, random_state=101)

# %%
inputs = pretrained_model.input
pooling_layer = GlobalAveragePooling2D()(pretrained_model.output)
drop_layer = Dropout(0.20)(pooling_layer)
x_layer = Dense(256, activation='relu')(drop_layer)
drop_layer1 = Dropout(0.5)(x_layer)
outputs = Dense(len(labels), activation='softmax')(drop_layer1)

model = Model(inputs=inputs, outputs=outputs)

# %%
adam = Adam(lr=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(x_train, y_train, batch_size=64, epochs=80, verbose=2, validation_data=(x_val, y_val))
# Out:
# /home/csci8523/attan005/.local/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/80
# 20/20 - 80s - loss: 3.0192 - accuracy: 0.1437 - val_loss: 3.0506 - val_accuracy: 0.0405 - 80s/epoch - 4s/step
# Epoch 2/80
# 20/20 - 67s - loss: 2.3705 - accuracy: 0.3048 - val_loss: 3.0781 - val_accuracy: 0.0405 - 67s/epoch - 3s/step
# Epoch 3/80
# 20/20 - 65s - loss: 2.0253 - accuracy: 0.3675 - val_loss: 3.1290 - val_accuracy: 0.0429 - 65s/epoch - 3s/step
# Epoch 4/80
# 20/20 - 64s - loss: 1.7278 - accuracy: 0.4683 - val_loss: 3.2165 - val_accuracy: 0.0429 - 64s/epoch - 3s/step
# Epoch 5/80
# 20/20 - 65s - loss: 1.5063 - accuracy: 0.5286 - val_loss: 3.3481 - val_accuracy: 0.0405 - 65s/epoch - 3s/step
# Epoch 6/80
# 20/20 - 64s - loss: 1.2544 - accuracy: 0.5881 - val_loss: 3.5475 - val_accuracy: 0.0405 - 64s/epoch - 3s/step
# Epoch 7/80
# 20/20 - 65s - loss: 1.1172 - accuracy: 0.6437 - val_loss: 3.7206 - val_accuracy: 0.0429 - 65s/epoch - 3s/step
# Epoch 8/80
# 20/20 - 64s - loss: 0.8959 - accuracy: 0.7143 - val_loss: 3.9392 - val_accuracy: 0.0476 - 64s/epoch - 3s/step
# Epoch 9/80
# 20/20 - 64s - loss: 0.7922 - accuracy: 0.7389 - val_loss: 4.4713 - val_accuracy: 0.0571 - 64s/epoch - 3s/step
# Epoch 10/80
# 20/20 - 65s - loss: 0.6904 - accuracy: 0.7778 - val_loss: 4.6763 - val_accuracy: 0.0381 - 65s/epoch - 3s/step
# Epoch 11/80
# 20/20 - 64s - loss: 0.5590 - accuracy: 0.8238 - val_loss: 6.6940 - val_accuracy: 0.0571 - 64s/epoch - 3s/step
# Epoch 12/80
# 20/20 - 64s - loss: 0.5247 - accuracy: 0.8437 - val_loss: 6.9136 - val_accuracy: 0.0595 - 64s/epoch - 3s/step
# Epoch 13/80
# 20/20 - 64s - loss: 0.4279 - accuracy: 0.8675 - val_loss: 6.2909 - val_accuracy: 0.0667 - 64s/epoch - 3s/step
# Epoch 14/80
# 20/20 - 64s - loss: 0.3888 - accuracy: 0.8754 - val_loss: 5.5670 - val_accuracy: 0.0619 - 64s/epoch - 3s/step
# Epoch 15/80
# 20/20 - 64s - loss: 0.3531 - accuracy: 0.8897 - val_loss: 7.8730 - val_accuracy: 0.0738 - 64s/epoch - 3s/step
# Epoch 16/80
# 20/20 - 65s - loss: 0.3216 - accuracy: 0.9111 - val_loss: 9.3335 - val_accuracy: 0.0881 - 65s/epoch - 3s/step
# Epoch 17/80
# 20/20 - 64s - loss: 0.2510 - accuracy: 0.9222 - val_loss: 7.3196 - val_accuracy: 0.1071 - 64s/epoch - 3s/step
# Epoch 18/80
# 20/20 - 64s - loss: 0.2459 - accuracy: 0.9206 - val_loss: 6.3261 - val_accuracy: 0.1238 - 64s/epoch - 3s/step
# Epoch 19/80
# 20/20 - 64s - loss: 0.2415 - accuracy: 0.9198 - val_loss: 6.5720 - val_accuracy: 0.1548 - 64s/epoch - 3s/step
# Epoch 20/80
# 20/20 - 65s - loss: 0.2559 - accuracy: 0.9206 - val_loss: 6.6007 - val_accuracy: 0.1476 - 65s/epoch - 3s/step
# Epoch 21/80
# 20/20 - 65s - loss: 0.2611 - accuracy: 0.9262 - val_loss: 5.3291 - val_accuracy: 0.1881 - 65s/epoch - 3s/step
# Epoch 22/80
# 20/20 - 64s - loss: 0.2114 - accuracy: 0.9365 - val_loss: 6.5666 - val_accuracy: 0.1500 - 64s/epoch - 3s/step
# Epoch 23/80
# 20/20 - 64s - loss: 0.2308 - accuracy: 0.9294 - val_loss: 4.3605 - val_accuracy: 0.2571 - 64s/epoch - 3s/step
# Epoch 24/80
# 20/20 - 63s - loss: 0.1507 - accuracy: 0.9532 - val_loss: 4.1015 - val_accuracy: 0.2714 - 63s/epoch - 3s/step
# Epoch 25/80
# 20/20 - 63s - loss: 0.1566 - accuracy: 0.9508 - val_loss: 4.2776 - val_accuracy: 0.2452 - 63s/epoch - 3s/step
# Epoch 26/80
# 20/20 - 63s - loss: 0.1503 - accuracy: 0.9508 - val_loss: 3.7030 - val_accuracy: 0.3310 - 63s/epoch - 3s/step
# Epoch 27/80
# 20/20 - 63s - loss: 0.1756 - accuracy: 0.9492 - val_loss: 2.6951 - val_accuracy: 0.4833 - 63s/epoch - 3s/step
# Epoch 28/80
# 20/20 - 64s - loss: 0.1991 - accuracy: 0.9429 - val_loss: 2.3516 - val_accuracy: 0.5357 - 64s/epoch - 3s/step
# Epoch 29/80
# 20/20 - 64s - loss: 0.1432 - accuracy: 0.9548 - val_loss: 1.9955 - val_accuracy: 0.5595 - 64s/epoch - 3s/step
# Epoch 30/80
# 20/20 - 63s - loss: 0.1345 - accuracy: 0.9563 - val_loss: 2.2886 - val_accuracy: 0.5524 - 63s/epoch - 3s/step
# Epoch 31/80
# 20/20 - 63s - loss: 0.1205 - accuracy: 0.9611 - val_loss: 2.1168 - val_accuracy: 0.5881 - 63s/epoch - 3s/step
# Epoch 32/80
# 20/20 - 64s - loss: 0.1940 - accuracy: 0.9437 - val_loss: 2.2674 - val_accuracy: 0.5738 - 64s/epoch - 3s/step
# Epoch 33/80
# 20/20 - 64s - loss: 0.2071 - accuracy: 0.9452 - val_loss: 1.5654 - val_accuracy: 0.6571 - 64s/epoch - 3s/step
# Epoch 34/80
# 20/20 - 64s - loss: 0.1780 - accuracy: 0.9484 - val_loss: 1.4951 - val_accuracy: 0.6714 - 64s/epoch - 3s/step
# Epoch 35/80
# 20/20 - 64s - loss: 0.1341 - accuracy: 0.9611 - val_loss: 1.9766 - val_accuracy: 0.5881 - 64s/epoch - 3s/step
# Epoch 36/80
# 20/20 - 64s - loss: 0.1610 - accuracy: 0.9540 - val_loss: 1.4896 - val_accuracy: 0.6810 - 64s/epoch - 3s/step
# Epoch 37/80
# 20/20 - 64s - loss: 0.1209 - accuracy: 0.9587 - val_loss: 1.7762 - val_accuracy: 0.5881 - 64s/epoch - 3s/step
# Epoch 38/80
# 20/20 - 64s - loss: 0.1090 - accuracy: 0.9659 - val_loss: 1.6249 - val_accuracy: 0.6643 - 64s/epoch - 3s/step
# Epoch 39/80
# 20/20 - 64s - loss: 0.1091 - accuracy: 0.9690 - val_loss: 1.2409 - val_accuracy: 0.7238 - 64s/epoch - 3s/step
# Epoch 40/80
# 20/20 - 63s - loss: 0.1166 - accuracy: 0.9683 - val_loss: 1.4099 - val_accuracy: 0.6881 - 63s/epoch - 3s/step
# Epoch 41/80
# 20/20 - 64s - loss: 0.0932 - accuracy: 0.9762 - val_loss: 1.2288 - val_accuracy: 0.7286 - 64s/epoch - 3s/step
# Epoch 42/80
# 20/20 - 64s - loss: 0.1279 - accuracy: 0.9635 - val_loss: 1.3273 - val_accuracy: 0.7190 - 64s/epoch - 3s/step
# Epoch 43/80
# 20/20 - 64s - loss: 0.0738 - accuracy: 0.9786 - val_loss: 1.3330 - val_accuracy: 0.7071 - 64s/epoch - 3s/step
# Epoch 44/80
# 20/20 - 64s - loss: 0.0657 - accuracy: 0.9849 - val_loss: 1.2009 - val_accuracy: 0.7357 - 64s/epoch - 3s/step
# Epoch 45/80
# 20/20 - 64s - loss: 0.0707 - accuracy: 0.9833 - val_loss: 1.9831 - val_accuracy: 0.6643 - 64s/epoch - 3s/step
# Epoch 46/80
# 20/20 - 63s - loss: 0.0776 - accuracy: 0.9794 - val_loss: 1.4754 - val_accuracy: 0.7167 - 63s/epoch - 3s/step
# Epoch 47/80
# 20/20 - 63s - loss: 0.0666 - accuracy: 0.9857 - val_loss: 1.2257 - val_accuracy: 0.7333 - 63s/epoch - 3s/step
# Epoch 48/80
# 20/20 - 64s - loss: 0.0851 - accuracy: 0.9738 - val_loss: 1.6795 - val_accuracy: 0.6881 - 64s/epoch - 3s/step
# Epoch 49/80
# 20/20 - 63s - loss: 0.0938 - accuracy: 0.9794 - val_loss: 1.4203 - val_accuracy: 0.7143 - 63s/epoch - 3s/step
# Epoch 50/80
# 20/20 - 63s - loss: 0.0800 - accuracy: 0.9746 - val_loss: 1.5184 - val_accuracy: 0.7071 - 63s/epoch - 3s/step
# Epoch 51/80
# 20/20 - 63s - loss: 0.1066 - accuracy: 0.9683 - val_loss: 2.5027 - val_accuracy: 0.5881 - 63s/epoch - 3s/step
# Epoch 52/80
# 20/20 - 63s - loss: 0.0997 - accuracy: 0.9714 - val_loss: 1.8481 - val_accuracy: 0.6714 - 63s/epoch - 3s/step
# Epoch 53/80
# 20/20 - 63s - loss: 0.0730 - accuracy: 0.9754 - val_loss: 1.2234 - val_accuracy: 0.7452 - 63s/epoch - 3s/step
# Epoch 54/80
# 20/20 - 63s - loss: 0.0585 - accuracy: 0.9833 - val_loss: 1.5301 - val_accuracy: 0.6833 - 63s/epoch - 3s/step
# Epoch 55/80
# 20/20 - 61s - loss: 0.1069 - accuracy: 0.9675 - val_loss: 1.2372 - val_accuracy: 0.7190 - 61s/epoch - 3s/step
# Epoch 56/80
# 20/20 - 61s - loss: 0.0902 - accuracy: 0.9778 - val_loss: 1.4770 - val_accuracy: 0.6976 - 61s/epoch - 3s/step
# Epoch 57/80
# 20/20 - 61s - loss: 0.1019 - accuracy: 0.9714 - val_loss: 1.2483 - val_accuracy: 0.7381 - 61s/epoch - 3s/step
# Epoch 58/80
# 20/20 - 61s - loss: 0.0843 - accuracy: 0.9762 - val_loss: 1.6900 - val_accuracy: 0.6786 - 61s/epoch - 3s/step
# Epoch 59/80
# 20/20 - 61s - loss: 0.0780 - accuracy: 0.9722 - val_loss: 1.5099 - val_accuracy: 0.7119 - 61s/epoch - 3s/step
# Epoch 60/80
# 20/20 - 61s - loss: 0.1338 - accuracy: 0.9627 - val_loss: 1.4454 - val_accuracy: 0.7000 - 61s/epoch - 3s/step
# Epoch 61/80
# 20/20 - 61s - loss: 0.1037 - accuracy: 0.9738 - val_loss: 1.3149 - val_accuracy: 0.7333 - 61s/epoch - 3s/step
# Epoch 62/80
# 20/20 - 61s - loss: 0.1446 - accuracy: 0.9635 - val_loss: 1.7599 - val_accuracy: 0.6714 - 61s/epoch - 3s/step
# Epoch 63/80
# 20/20 - 60s - loss: 0.0859 - accuracy: 0.9762 - val_loss: 1.8512 - val_accuracy: 0.6357 - 60s/epoch - 3s/step
# Epoch 64/80
# 20/20 - 61s - loss: 0.0725 - accuracy: 0.9817 - val_loss: 1.3543 - val_accuracy: 0.7310 - 61s/epoch - 3s/step
# Epoch 65/80
# 20/20 - 62s - loss: 0.0539 - accuracy: 0.9786 - val_loss: 1.2057 - val_accuracy: 0.7476 - 62s/epoch - 3s/step
# Epoch 66/80
# 20/20 - 61s - loss: 0.0598 - accuracy: 0.9786 - val_loss: 1.7575 - val_accuracy: 0.7071 - 61s/epoch - 3s/step
# Epoch 67/80
# 20/20 - 61s - loss: 0.0477 - accuracy: 0.9865 - val_loss: 1.4556 - val_accuracy: 0.7071 - 61s/epoch - 3s/step
# Epoch 68/80
# 20/20 - 61s - loss: 0.0358 - accuracy: 0.9889 - val_loss: 1.2919 - val_accuracy: 0.7452 - 61s/epoch - 3s/step
# Epoch 69/80
# 20/20 - 61s - loss: 0.0364 - accuracy: 0.9889 - val_loss: 1.4570 - val_accuracy: 0.7452 - 61s/epoch - 3s/step
# Epoch 70/80
# 20/20 - 61s - loss: 0.0378 - accuracy: 0.9889 - val_loss: 1.2394 - val_accuracy: 0.7524 - 61s/epoch - 3s/step
# Epoch 71/80
# 20/20 - 61s - loss: 0.0430 - accuracy: 0.9857 - val_loss: 1.3619 - val_accuracy: 0.7381 - 61s/epoch - 3s/step
# Epoch 72/80
# 20/20 - 61s - loss: 0.0947 - accuracy: 0.9770 - val_loss: 1.3399 - val_accuracy: 0.7405 - 61s/epoch - 3s/step
# Epoch 73/80
# 20/20 - 61s - loss: 0.0634 - accuracy: 0.9794 - val_loss: 1.7199 - val_accuracy: 0.6643 - 61s/epoch - 3s/step
# Epoch 74/80
# 20/20 - 61s - loss: 0.0628 - accuracy: 0.9802 - val_loss: 1.3549 - val_accuracy: 0.7310 - 61s/epoch - 3s/step
# Epoch 75/80
# 20/20 - 61s - loss: 0.0592 - accuracy: 0.9841 - val_loss: 1.0622 - val_accuracy: 0.7786 - 61s/epoch - 3s/step
# Epoch 76/80
# 20/20 - 61s - loss: 0.0473 - accuracy: 0.9881 - val_loss: 1.5208 - val_accuracy: 0.7286 - 61s/epoch - 3s/step
# Epoch 77/80
# 20/20 - 61s - loss: 0.0837 - accuracy: 0.9810 - val_loss: 1.3650 - val_accuracy: 0.7214 - 61s/epoch - 3s/step
# Epoch 78/80
# 20/20 - 61s - loss: 0.1027 - accuracy: 0.9754 - val_loss: 1.4704 - val_accuracy: 0.7452 - 61s/epoch - 3s/step
# Epoch 79/80
# 20/20 - 61s - loss: 0.0836 - accuracy: 0.9786 - val_loss: 1.5225 - val_accuracy: 0.7143 - 61s/epoch - 3s/step
# Epoch 80/80
# 20/20 - 61s - loss: 0.0711 - accuracy: 0.9825 - val_loss: 1.2637 - val_accuracy: 0.7524 - 61s/epoch - 3s/step

# %%
model.save_weights("uc_merced_final_1_t.h5")

# %%
accuracy = model_fit_history.history['accuracy']
val_accuracy = model_fit_history.history['val_accuracy']
loss = model_fit_history.history['loss']
val_loss = model_fit_history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'r', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
y_pred = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 14/14 [==============================] - 4s 205ms/step

# %%
y_test = np.nonzero(y_test)[1]
accuracy = accuracy_score(y_test, y_pred)
print(f'Model predication accuracy: {accuracy:.3f}')
print(f'\nClassification report:\n {classification_report(y_test, y_pred)}')
# Out:
# Model predication accuracy: 0.714
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89        20
#            1       0.54      0.96      0.69        23
#            2       0.61      0.82      0.70        17
#            3       0.88      0.94      0.91        16
#            4       0.75      0.47      0.58        19
#            5       1.00      0.94      0.97        18
#            6       0.50      0.17      0.25        12
#            7       0.92      1.00      0.96        24
#            8       0.67      0.64      0.65        22
#            9       0.82      0.75      0.78        24
#           10       1.00      0.45      0.62        22
#           11       0.42      0.88      0.57        16
#           12       0.52      0.71      0.60        17
#           13       0.76      0.83      0.79        23
#           14       0.50      0.69      0.58        16
#           15       0.92      0.82      0.87        28
#           16       0.94      0.65      0.77        26
#           17       0.70      1.00      0.83        19
#           18       0.73      0.47      0.57        17
#           19       0.75      0.43      0.55        21
#           20       0.46      0.30      0.36        20
#
#     accuracy                           0.71       420
#    macro avg       0.73      0.70      0.69       420
# weighted avg       0.75      0.71      0.71       420
