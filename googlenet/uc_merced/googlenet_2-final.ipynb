# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import os

from skimage.io import imread, imsave

from keras import applications
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras import Model

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %matplotlib inline

# %%
source_dir = os.path.join('UCMerced_LandUse', 'UCMerced_LandUse', 'Images')

# %%
plt.imshow(imread('UCMerced_LandUse/UCMerced_LandUse/Images/beach/beach01.tif'))
plt.axis('off')
plt.show()

# %%
labels = os.listdir(source_dir)
# Out:
# ['agricultural', 'airplane', 'baseballdiamond', 'beach', 'buildings', 'chaparral', 'denseresidential', 'forest', 'freeway', 'golfcourse', 'harbor', 'intersection', 'mediumresidential', 'mobilehomepark', 'overpass', 'parkinglot', 'river', 'runway', 'sparseresidential', 'storagetanks', 'tenniscourt']

# %%
pretrained_model = applications.InceptionV3(include_top=False, weights='imagenet')
pretrained_model.trainable = False

# %%
image_data_generator = ImageDataGenerator(rescale=1/255.0)
image_generator = image_data_generator.flow_from_directory(source_dir,
                                                        batch_size=64,
                                                        shuffle=False
                                                        )
count = 0
X_batches, Y_batches = [], []
for X, Y in image_generator:
    X_batches.append(X)
    Y_batches.append(Y)
    count += X.shape[0]
    if count >= image_generator.n:
        break

x_data = np.concatenate(X_batches)
y_data = np.concatenate(Y_batches)
# Out:
# Found 2100 images belonging to 21 classes.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size = 0.4, random_state=101)
x_test, x_val, y_test, y_val = train_test_split(x_val, y_val, test_size = 0.5, random_state=101)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1260, 256, 256, 3)
# (1260, 21)

# %%
inputs = pretrained_model.input
pooling_layer = GlobalAveragePooling2D()(pretrained_model.output)
drop_layer = Dropout(0.20)(pooling_layer)
x_layer = Dense(256, activation='relu')(drop_layer)
drop_layer1 = Dropout(0.5)(x_layer)
outputs = Dense(len(labels), activation='softmax')(drop_layer1)

model = Model(inputs=inputs, outputs=outputs)

# %%
adam = Adam(lr=0.001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model_fit_history = model.fit(x_train, y_train, batch_size=64, epochs=50, verbose=2, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 20/20 - 22s - loss: 2.5017 - accuracy: 0.2714 - val_loss: 1.3248 - val_accuracy: 0.6548 - 22s/epoch - 1s/step
# Epoch 2/50
# 20/20 - 14s - loss: 1.2200 - accuracy: 0.6524 - val_loss: 0.6774 - val_accuracy: 0.8238 - 14s/epoch - 720ms/step
# Epoch 3/50
# 20/20 - 15s - loss: 0.7519 - accuracy: 0.7778 - val_loss: 0.4823 - val_accuracy: 0.8667 - 15s/epoch - 729ms/step
# Epoch 4/50
# 20/20 - 14s - loss: 0.5307 - accuracy: 0.8460 - val_loss: 0.4359 - val_accuracy: 0.8762 - 14s/epoch - 715ms/step
# Epoch 5/50
# 20/20 - 15s - loss: 0.4367 - accuracy: 0.8619 - val_loss: 0.3649 - val_accuracy: 0.8857 - 15s/epoch - 736ms/step
# Epoch 6/50
# 20/20 - 14s - loss: 0.3562 - accuracy: 0.8952 - val_loss: 0.3520 - val_accuracy: 0.8952 - 14s/epoch - 723ms/step
# Epoch 7/50
# 20/20 - 15s - loss: 0.2789 - accuracy: 0.9278 - val_loss: 0.3738 - val_accuracy: 0.8786 - 15s/epoch - 725ms/step
# Epoch 8/50
# 20/20 - 15s - loss: 0.2418 - accuracy: 0.9341 - val_loss: 0.3392 - val_accuracy: 0.8952 - 15s/epoch - 732ms/step
# Epoch 9/50
# 20/20 - 12s - loss: 0.2231 - accuracy: 0.9302 - val_loss: 0.3071 - val_accuracy: 0.9095 - 12s/epoch - 583ms/step
# Epoch 10/50
# 20/20 - 11s - loss: 0.1961 - accuracy: 0.9405 - val_loss: 0.2934 - val_accuracy: 0.9000 - 11s/epoch - 558ms/step
# Epoch 11/50
# 20/20 - 11s - loss: 0.1626 - accuracy: 0.9595 - val_loss: 0.3190 - val_accuracy: 0.8976 - 11s/epoch - 556ms/step
# Epoch 12/50
# 20/20 - 11s - loss: 0.1520 - accuracy: 0.9595 - val_loss: 0.2997 - val_accuracy: 0.9048 - 11s/epoch - 560ms/step
# Epoch 13/50
# 20/20 - 11s - loss: 0.1455 - accuracy: 0.9619 - val_loss: 0.2926 - val_accuracy: 0.9119 - 11s/epoch - 553ms/step
# Epoch 14/50
# 20/20 - 11s - loss: 0.1202 - accuracy: 0.9690 - val_loss: 0.2750 - val_accuracy: 0.9190 - 11s/epoch - 557ms/step
# Epoch 15/50
# 20/20 - 11s - loss: 0.1186 - accuracy: 0.9722 - val_loss: 0.2843 - val_accuracy: 0.9119 - 11s/epoch - 560ms/step
# Epoch 16/50
# 20/20 - 11s - loss: 0.1074 - accuracy: 0.9659 - val_loss: 0.2720 - val_accuracy: 0.9143 - 11s/epoch - 557ms/step
# Epoch 17/50
# 20/20 - 11s - loss: 0.0868 - accuracy: 0.9778 - val_loss: 0.2814 - val_accuracy: 0.9143 - 11s/epoch - 556ms/step
# Epoch 18/50
# 20/20 - 11s - loss: 0.0835 - accuracy: 0.9802 - val_loss: 0.2669 - val_accuracy: 0.9238 - 11s/epoch - 560ms/step
# Epoch 19/50
# 20/20 - 11s - loss: 0.0801 - accuracy: 0.9786 - val_loss: 0.2839 - val_accuracy: 0.9190 - 11s/epoch - 555ms/step
# Epoch 20/50
# 20/20 - 11s - loss: 0.0726 - accuracy: 0.9810 - val_loss: 0.2775 - val_accuracy: 0.9071 - 11s/epoch - 552ms/step
# Epoch 21/50
# 20/20 - 11s - loss: 0.0759 - accuracy: 0.9794 - val_loss: 0.2761 - val_accuracy: 0.9190 - 11s/epoch - 553ms/step
# Epoch 22/50
# 20/20 - 11s - loss: 0.0569 - accuracy: 0.9865 - val_loss: 0.2563 - val_accuracy: 0.9214 - 11s/epoch - 554ms/step
# Epoch 23/50
# 20/20 - 11s - loss: 0.0568 - accuracy: 0.9881 - val_loss: 0.3011 - val_accuracy: 0.9167 - 11s/epoch - 551ms/step
# Epoch 24/50
# 20/20 - 11s - loss: 0.0535 - accuracy: 0.9857 - val_loss: 0.2659 - val_accuracy: 0.9167 - 11s/epoch - 550ms/step
# Epoch 25/50
# 20/20 - 11s - loss: 0.0489 - accuracy: 0.9905 - val_loss: 0.2718 - val_accuracy: 0.9167 - 11s/epoch - 554ms/step
# Epoch 26/50
# 20/20 - 11s - loss: 0.0416 - accuracy: 0.9929 - val_loss: 0.2840 - val_accuracy: 0.9071 - 11s/epoch - 553ms/step
# Epoch 27/50
# 20/20 - 11s - loss: 0.0502 - accuracy: 0.9873 - val_loss: 0.2484 - val_accuracy: 0.9262 - 11s/epoch - 561ms/step
# Epoch 28/50
# 20/20 - 11s - loss: 0.0481 - accuracy: 0.9921 - val_loss: 0.2766 - val_accuracy: 0.9190 - 11s/epoch - 549ms/step
# Epoch 29/50
# 20/20 - 11s - loss: 0.0480 - accuracy: 0.9873 - val_loss: 0.2833 - val_accuracy: 0.9095 - 11s/epoch - 555ms/step
# Epoch 30/50
# 20/20 - 11s - loss: 0.0449 - accuracy: 0.9913 - val_loss: 0.2824 - val_accuracy: 0.9214 - 11s/epoch - 553ms/step
# Epoch 31/50
# 20/20 - 11s - loss: 0.0610 - accuracy: 0.9833 - val_loss: 0.2728 - val_accuracy: 0.9238 - 11s/epoch - 558ms/step
# Epoch 32/50
# 20/20 - 11s - loss: 0.0526 - accuracy: 0.9889 - val_loss: 0.3070 - val_accuracy: 0.9095 - 11s/epoch - 561ms/step
# Epoch 33/50
# 20/20 - 11s - loss: 0.0341 - accuracy: 0.9952 - val_loss: 0.2941 - val_accuracy: 0.9238 - 11s/epoch - 551ms/step
# Epoch 34/50
# 20/20 - 11s - loss: 0.0398 - accuracy: 0.9921 - val_loss: 0.2898 - val_accuracy: 0.9262 - 11s/epoch - 555ms/step
# Epoch 35/50
# 20/20 - 11s - loss: 0.0353 - accuracy: 0.9937 - val_loss: 0.2987 - val_accuracy: 0.9143 - 11s/epoch - 556ms/step
# Epoch 36/50
# 20/20 - 11s - loss: 0.0353 - accuracy: 0.9913 - val_loss: 0.3079 - val_accuracy: 0.9048 - 11s/epoch - 557ms/step
# Epoch 37/50
# 20/20 - 11s - loss: 0.0328 - accuracy: 0.9921 - val_loss: 0.2944 - val_accuracy: 0.9095 - 11s/epoch - 564ms/step
# Epoch 38/50
# 20/20 - 11s - loss: 0.0292 - accuracy: 0.9968 - val_loss: 0.3032 - val_accuracy: 0.9190 - 11s/epoch - 558ms/step
# Epoch 39/50
# 20/20 - 11s - loss: 0.0300 - accuracy: 0.9913 - val_loss: 0.2685 - val_accuracy: 0.9262 - 11s/epoch - 554ms/step
# Epoch 40/50
# 20/20 - 11s - loss: 0.0341 - accuracy: 0.9929 - val_loss: 0.2981 - val_accuracy: 0.9095 - 11s/epoch - 557ms/step
# Epoch 41/50
# 20/20 - 11s - loss: 0.0351 - accuracy: 0.9944 - val_loss: 0.2997 - val_accuracy: 0.9190 - 11s/epoch - 558ms/step
# Epoch 42/50
# 20/20 - 11s - loss: 0.0282 - accuracy: 0.9944 - val_loss: 0.2741 - val_accuracy: 0.9310 - 11s/epoch - 552ms/step
# Epoch 43/50
# 20/20 - 11s - loss: 0.0254 - accuracy: 0.9937 - val_loss: 0.3045 - val_accuracy: 0.9143 - 11s/epoch - 555ms/step
# Epoch 44/50
# 20/20 - 11s - loss: 0.0231 - accuracy: 0.9960 - val_loss: 0.3088 - val_accuracy: 0.9143 - 11s/epoch - 554ms/step
# Epoch 45/50
# 20/20 - 11s - loss: 0.0227 - accuracy: 0.9944 - val_loss: 0.3256 - val_accuracy: 0.9095 - 11s/epoch - 564ms/step
# Epoch 46/50
# 20/20 - 11s - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.2972 - val_accuracy: 0.9310 - 11s/epoch - 550ms/step
# Epoch 47/50
# 20/20 - 11s - loss: 0.0267 - accuracy: 0.9929 - val_loss: 0.3076 - val_accuracy: 0.9286 - 11s/epoch - 556ms/step
# Epoch 48/50
# 20/20 - 11s - loss: 0.0213 - accuracy: 0.9968 - val_loss: 0.3342 - val_accuracy: 0.9119 - 11s/epoch - 565ms/step
# Epoch 49/50
# 20/20 - 11s - loss: 0.0251 - accuracy: 0.9960 - val_loss: 0.3070 - val_accuracy: 0.9238 - 11s/epoch - 556ms/step
# Epoch 50/50
# 20/20 - 11s - loss: 0.0184 - accuracy: 0.9944 - val_loss: 0.3439 - val_accuracy: 0.9190 - 11s/epoch - 557ms/step

# %%
model.save_weights("model_dense_pre.h5")

# %%
for layer in pretrained_model.layers[:249]:
   layer.trainable = False
for layer in pretrained_model.layers[249:]:
   layer.trainable = True

inputs = pretrained_model.input
pooling_layer = GlobalAveragePooling2D()(pretrained_model.output)
drop_layer = Dropout(0.20)(pooling_layer)
x_layer = Dense(256, activation='relu')(drop_layer)
drop_layer1 = Dropout(0.5)(x_layer)
outputs = Dense(len(labels), activation='softmax')(drop_layer1)

model = Model(inputs=inputs, outputs=outputs)
model.load_weights("model_dense_pre.h5")
adam = Adam()
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64, epochs=100, verbose=2, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 20/20 - 22s - loss: 0.4699 - accuracy: 0.8635 - val_loss: 1.5755 - val_accuracy: 0.7524 - 22s/epoch - 1s/step
# Epoch 2/100
# 20/20 - 15s - loss: 0.1352 - accuracy: 0.9563 - val_loss: 0.9750 - val_accuracy: 0.8667 - 15s/epoch - 773ms/step
# Epoch 3/100
# 20/20 - 15s - loss: 0.0456 - accuracy: 0.9865 - val_loss: 0.8389 - val_accuracy: 0.9095 - 15s/epoch - 767ms/step
# Epoch 4/100
# 20/20 - 15s - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.5005 - val_accuracy: 0.9381 - 15s/epoch - 770ms/step
# Epoch 5/100
# 20/20 - 15s - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.3982 - val_accuracy: 0.9333 - 15s/epoch - 770ms/step
# Epoch 6/100
# 20/20 - 15s - loss: 0.0234 - accuracy: 0.9960 - val_loss: 0.4630 - val_accuracy: 0.9333 - 15s/epoch - 772ms/step
# Epoch 7/100
# 20/20 - 15s - loss: 0.0234 - accuracy: 0.9929 - val_loss: 1.0045 - val_accuracy: 0.8881 - 15s/epoch - 773ms/step
# Epoch 8/100
# 20/20 - 15s - loss: 0.0107 - accuracy: 0.9976 - val_loss: 1.3345 - val_accuracy: 0.8595 - 15s/epoch - 774ms/step
# Epoch 9/100
# 20/20 - 16s - loss: 0.0238 - accuracy: 0.9976 - val_loss: 0.4224 - val_accuracy: 0.9286 - 16s/epoch - 776ms/step
# Epoch 10/100
# 20/20 - 16s - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.3132 - val_accuracy: 0.9476 - 16s/epoch - 777ms/step
# Epoch 11/100
# 20/20 - 15s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2808 - val_accuracy: 0.9452 - 15s/epoch - 774ms/step
# Epoch 12/100
# 20/20 - 15s - loss: 0.0141 - accuracy: 0.9944 - val_loss: 0.7845 - val_accuracy: 0.9024 - 15s/epoch - 773ms/step
# Epoch 13/100
# 20/20 - 15s - loss: 0.0452 - accuracy: 0.9881 - val_loss: 2.5462 - val_accuracy: 0.7976 - 15s/epoch - 772ms/step
# Epoch 14/100
# 20/20 - 15s - loss: 0.0879 - accuracy: 0.9794 - val_loss: 10.4426 - val_accuracy: 0.5286 - 15s/epoch - 768ms/step
# Epoch 15/100
# 20/20 - 15s - loss: 0.0582 - accuracy: 0.9833 - val_loss: 1.9027 - val_accuracy: 0.8262 - 15s/epoch - 769ms/step
# Epoch 16/100
# 20/20 - 15s - loss: 0.0955 - accuracy: 0.9810 - val_loss: 9.5245 - val_accuracy: 0.6500 - 15s/epoch - 769ms/step
# Epoch 17/100
# 20/20 - 15s - loss: 0.0635 - accuracy: 0.9810 - val_loss: 4.8275 - val_accuracy: 0.7143 - 15s/epoch - 769ms/step
# Epoch 18/100
# 20/20 - 15s - loss: 0.0675 - accuracy: 0.9825 - val_loss: 4.9007 - val_accuracy: 0.7262 - 15s/epoch - 765ms/step
# Epoch 19/100
# 20/20 - 15s - loss: 0.0188 - accuracy: 0.9960 - val_loss: 1.3274 - val_accuracy: 0.8548 - 15s/epoch - 775ms/step
# Epoch 20/100
# 20/20 - 16s - loss: 0.0201 - accuracy: 0.9952 - val_loss: 1.1939 - val_accuracy: 0.8524 - 16s/epoch - 775ms/step
# Epoch 21/100
# 20/20 - 15s - loss: 0.0106 - accuracy: 0.9976 - val_loss: 1.3722 - val_accuracy: 0.8714 - 15s/epoch - 771ms/step
# Epoch 22/100
# 20/20 - 15s - loss: 0.0317 - accuracy: 0.9952 - val_loss: 1.0318 - val_accuracy: 0.8762 - 15s/epoch - 774ms/step
# Epoch 23/100
# 20/20 - 15s - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.5224 - val_accuracy: 0.9238 - 15s/epoch - 773ms/step
# Epoch 24/100
# 20/20 - 15s - loss: 0.0215 - accuracy: 0.9960 - val_loss: 0.4661 - val_accuracy: 0.9286 - 15s/epoch - 768ms/step
# Epoch 25/100
# 20/20 - 15s - loss: 0.0461 - accuracy: 0.9921 - val_loss: 0.3148 - val_accuracy: 0.9310 - 15s/epoch - 773ms/step
# Epoch 26/100
# 20/20 - 15s - loss: 0.0236 - accuracy: 0.9944 - val_loss: 0.3734 - val_accuracy: 0.9476 - 15s/epoch - 774ms/step
# Epoch 27/100
# 20/20 - 15s - loss: 0.0297 - accuracy: 0.9944 - val_loss: 0.5309 - val_accuracy: 0.9262 - 15s/epoch - 766ms/step
# Epoch 28/100
# 20/20 - 15s - loss: 0.0253 - accuracy: 0.9952 - val_loss: 0.3556 - val_accuracy: 0.9310 - 15s/epoch - 770ms/step
# Epoch 29/100
# 20/20 - 15s - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.3189 - val_accuracy: 0.9476 - 15s/epoch - 770ms/step
# Epoch 30/100
# 20/20 - 15s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.3205 - val_accuracy: 0.9548 - 15s/epoch - 772ms/step
# Epoch 31/100
# 20/20 - 15s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.9595 - 15s/epoch - 766ms/step
# Epoch 32/100
# 20/20 - 15s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9595 - 15s/epoch - 772ms/step
# Epoch 33/100
# 20/20 - 15s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9548 - 15s/epoch - 773ms/step
# Epoch 34/100
# 20/20 - 15s - loss: 9.2041e-04 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9595 - 15s/epoch - 771ms/step
# Epoch 35/100
# 20/20 - 15s - loss: 6.6095e-04 - accuracy: 1.0000 - val_loss: 0.2359 - val_accuracy: 0.9548 - 15s/epoch - 771ms/step
# Epoch 36/100
# 20/20 - 15s - loss: 3.4829e-04 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9571 - 15s/epoch - 772ms/step
# Epoch 37/100
# 20/20 - 15s - loss: 7.5275e-04 - accuracy: 1.0000 - val_loss: 0.2388 - val_accuracy: 0.9619 - 15s/epoch - 773ms/step
# Epoch 38/100
# 20/20 - 15s - loss: 7.8125e-04 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9619 - 15s/epoch - 769ms/step
# Epoch 39/100
# 20/20 - 15s - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.2539 - val_accuracy: 0.9571 - 15s/epoch - 769ms/step
# Epoch 40/100
# 20/20 - 15s - loss: 0.0024 - accuracy: 0.9984 - val_loss: 0.3539 - val_accuracy: 0.9429 - 15s/epoch - 768ms/step
# Epoch 41/100
# 20/20 - 15s - loss: 0.0155 - accuracy: 0.9976 - val_loss: 0.3681 - val_accuracy: 0.9476 - 15s/epoch - 773ms/step
# Epoch 42/100
# 20/20 - 15s - loss: 0.0066 - accuracy: 0.9992 - val_loss: 0.4742 - val_accuracy: 0.9452 - 15s/epoch - 773ms/step
# Epoch 43/100
# 20/20 - 15s - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.3739 - val_accuracy: 0.9524 - 15s/epoch - 767ms/step
# Epoch 44/100
# 20/20 - 15s - loss: 0.0215 - accuracy: 0.9944 - val_loss: 0.7000 - val_accuracy: 0.9167 - 15s/epoch - 772ms/step
# Epoch 45/100
# 20/20 - 15s - loss: 0.0669 - accuracy: 0.9937 - val_loss: 1.6470 - val_accuracy: 0.8690 - 15s/epoch - 769ms/step
# Epoch 46/100
# 20/20 - 15s - loss: 0.0637 - accuracy: 0.9849 - val_loss: 2.7583 - val_accuracy: 0.8048 - 15s/epoch - 769ms/step
# Epoch 47/100
# 20/20 - 15s - loss: 0.0165 - accuracy: 0.9968 - val_loss: 0.7742 - val_accuracy: 0.9000 - 15s/epoch - 771ms/step
# Epoch 48/100
# 20/20 - 15s - loss: 0.0183 - accuracy: 0.9952 - val_loss: 0.5535 - val_accuracy: 0.9214 - 15s/epoch - 771ms/step
# Epoch 49/100
# 20/20 - 16s - loss: 0.0040 - accuracy: 0.9984 - val_loss: 1.6934 - val_accuracy: 0.8452 - 16s/epoch - 776ms/step
# Epoch 50/100
# 20/20 - 16s - loss: 0.0307 - accuracy: 0.9960 - val_loss: 0.8084 - val_accuracy: 0.8786 - 16s/epoch - 779ms/step
# Epoch 51/100
# 20/20 - 15s - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.6566 - val_accuracy: 0.9000 - 15s/epoch - 772ms/step
# Epoch 52/100
# 20/20 - 16s - loss: 0.0211 - accuracy: 0.9944 - val_loss: 0.3994 - val_accuracy: 0.9190 - 16s/epoch - 777ms/step
# Epoch 53/100
# 20/20 - 16s - loss: 0.0234 - accuracy: 0.9937 - val_loss: 0.5083 - val_accuracy: 0.9310 - 16s/epoch - 777ms/step
# Epoch 54/100
# 20/20 - 16s - loss: 0.0287 - accuracy: 0.9944 - val_loss: 1.2223 - val_accuracy: 0.9119 - 16s/epoch - 776ms/step
# Epoch 55/100
# 20/20 - 16s - loss: 0.0216 - accuracy: 0.9921 - val_loss: 2.1798 - val_accuracy: 0.8190 - 16s/epoch - 779ms/step
# Epoch 56/100
# 20/20 - 15s - loss: 0.0127 - accuracy: 0.9976 - val_loss: 1.1701 - val_accuracy: 0.9000 - 15s/epoch - 769ms/step
# Epoch 57/100
# 20/20 - 15s - loss: 0.0210 - accuracy: 0.9960 - val_loss: 0.8034 - val_accuracy: 0.9024 - 15s/epoch - 769ms/step
# Epoch 58/100
# 20/20 - 15s - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.4273 - val_accuracy: 0.9286 - 15s/epoch - 772ms/step
# Epoch 59/100
# 20/20 - 15s - loss: 0.0096 - accuracy: 0.9960 - val_loss: 0.6082 - val_accuracy: 0.9071 - 15s/epoch - 772ms/step
# Epoch 60/100
# 20/20 - 15s - loss: 0.0244 - accuracy: 0.9937 - val_loss: 0.3942 - val_accuracy: 0.9405 - 15s/epoch - 774ms/step
# Epoch 61/100
# 20/20 - 15s - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.3850 - val_accuracy: 0.9333 - 15s/epoch - 772ms/step
# Epoch 62/100
# 20/20 - 16s - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.3295 - val_accuracy: 0.9381 - 16s/epoch - 776ms/step
# Epoch 63/100
# 20/20 - 15s - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.3475 - val_accuracy: 0.9357 - 15s/epoch - 772ms/step
# Epoch 64/100
# 20/20 - 15s - loss: 0.0144 - accuracy: 0.9976 - val_loss: 0.3189 - val_accuracy: 0.9405 - 15s/epoch - 769ms/step
# Epoch 65/100
# 20/20 - 15s - loss: 0.0314 - accuracy: 0.9929 - val_loss: 0.4609 - val_accuracy: 0.9214 - 15s/epoch - 772ms/step
# Epoch 66/100
# 20/20 - 15s - loss: 0.0063 - accuracy: 0.9992 - val_loss: 0.4300 - val_accuracy: 0.9238 - 15s/epoch - 771ms/step
# Epoch 67/100
# 20/20 - 16s - loss: 0.0055 - accuracy: 0.9992 - val_loss: 0.3721 - val_accuracy: 0.9381 - 16s/epoch - 779ms/step
# Epoch 68/100
# 20/20 - 15s - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.2821 - val_accuracy: 0.9452 - 15s/epoch - 769ms/step
# Epoch 69/100
# 20/20 - 15s - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.2701 - val_accuracy: 0.9452 - 15s/epoch - 769ms/step
# Epoch 70/100
# 20/20 - 15s - loss: 0.0119 - accuracy: 0.9976 - val_loss: 0.2812 - val_accuracy: 0.9476 - 15s/epoch - 770ms/step
# Epoch 71/100
# 20/20 - 15s - loss: 0.0203 - accuracy: 0.9944 - val_loss: 0.7452 - val_accuracy: 0.9119 - 15s/epoch - 768ms/step
# Epoch 72/100
# 20/20 - 15s - loss: 0.0859 - accuracy: 0.9921 - val_loss: 0.7146 - val_accuracy: 0.9190 - 15s/epoch - 773ms/step
# Epoch 73/100
# 20/20 - 15s - loss: 0.0637 - accuracy: 0.9873 - val_loss: 1.4849 - val_accuracy: 0.8405 - 15s/epoch - 767ms/step
# Epoch 74/100
# 20/20 - 15s - loss: 0.0394 - accuracy: 0.9921 - val_loss: 1.4928 - val_accuracy: 0.8619 - 15s/epoch - 773ms/step
# Epoch 75/100
# 20/20 - 15s - loss: 0.0444 - accuracy: 0.9929 - val_loss: 2.1178 - val_accuracy: 0.8548 - 15s/epoch - 767ms/step
# Epoch 76/100
# 20/20 - 15s - loss: 0.0287 - accuracy: 0.9913 - val_loss: 1.3615 - val_accuracy: 0.8857 - 15s/epoch - 772ms/step
# Epoch 77/100
# 20/20 - 15s - loss: 0.0140 - accuracy: 0.9944 - val_loss: 0.4850 - val_accuracy: 0.9405 - 15s/epoch - 771ms/step
# Epoch 78/100
# 20/20 - 15s - loss: 0.0395 - accuracy: 0.9937 - val_loss: 0.5162 - val_accuracy: 0.9310 - 15s/epoch - 772ms/step
# Epoch 79/100
# 20/20 - 16s - loss: 0.0262 - accuracy: 0.9952 - val_loss: 0.3934 - val_accuracy: 0.9357 - 16s/epoch - 777ms/step
# Epoch 80/100
# 20/20 - 15s - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.3495 - val_accuracy: 0.9476 - 15s/epoch - 771ms/step
# Epoch 81/100
# 20/20 - 16s - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.3402 - val_accuracy: 0.9452 - 16s/epoch - 777ms/step
# Epoch 82/100
# 20/20 - 15s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3229 - val_accuracy: 0.9429 - 15s/epoch - 773ms/step
# Epoch 83/100
# 20/20 - 15s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3095 - val_accuracy: 0.9476 - 15s/epoch - 770ms/step
# Epoch 84/100
# 20/20 - 15s - loss: 0.0055 - accuracy: 0.9992 - val_loss: 0.2512 - val_accuracy: 0.9595 - 15s/epoch - 769ms/step
# Epoch 85/100
# 20/20 - 15s - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.3102 - val_accuracy: 0.9476 - 15s/epoch - 769ms/step
# Epoch 86/100
# 20/20 - 16s - loss: 8.0490e-04 - accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.9476 - 16s/epoch - 781ms/step
# Epoch 87/100
# 20/20 - 15s - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.3125 - val_accuracy: 0.9476 - 15s/epoch - 765ms/step
# Epoch 88/100
# 20/20 - 15s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.3162 - val_accuracy: 0.9476 - 15s/epoch - 772ms/step
# Epoch 89/100
# 20/20 - 15s - loss: 3.0923e-04 - accuracy: 1.0000 - val_loss: 0.3222 - val_accuracy: 0.9452 - 15s/epoch - 771ms/step
# Epoch 90/100
# 20/20 - 15s - loss: 0.0204 - accuracy: 0.9952 - val_loss: 0.3980 - val_accuracy: 0.9357 - 15s/epoch - 770ms/step
# Epoch 91/100
# 20/20 - 15s - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.6396 - val_accuracy: 0.9214 - 15s/epoch - 769ms/step
# Epoch 92/100
# 20/20 - 16s - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.4829 - val_accuracy: 0.9286 - 16s/epoch - 775ms/step
# Epoch 93/100
# 20/20 - 16s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.3752 - val_accuracy: 0.9452 - 16s/epoch - 778ms/step
# Epoch 94/100
# 20/20 - 15s - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.3723 - val_accuracy: 0.9429 - 15s/epoch - 770ms/step
# Epoch 95/100
# 20/20 - 15s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3787 - val_accuracy: 0.9452 - 15s/epoch - 774ms/step
# Epoch 96/100
# 20/20 - 15s - loss: 0.0060 - accuracy: 0.9992 - val_loss: 0.3534 - val_accuracy: 0.9452 - 15s/epoch - 770ms/step
# Epoch 97/100
# 20/20 - 16s - loss: 8.9189e-04 - accuracy: 1.0000 - val_loss: 0.3969 - val_accuracy: 0.9452 - 16s/epoch - 777ms/step
# Epoch 98/100
# 20/20 - 16s - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.4315 - val_accuracy: 0.9500 - 16s/epoch - 781ms/step
# Epoch 99/100
# 20/20 - 15s - loss: 0.0254 - accuracy: 0.9960 - val_loss: 0.4301 - val_accuracy: 0.9381 - 15s/epoch - 773ms/step
# Epoch 100/100
# 20/20 - 16s - loss: 0.0816 - accuracy: 0.9913 - val_loss: 0.4330 - val_accuracy: 0.9405 - 16s/epoch - 780ms/step

# %%
model.save_weights("uc_merced_final_2.h5")

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'r', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
y_pred = np.argmax(model.predict(x_test), axis=-1)
# Out:
# 14/14 [==============================] - 5s 270ms/step

# %%
y_test = np.nonzero(y_test)[1]
accuracy = accuracy_score(y_test, y_pred)
print(f'Model predication accuracy: {accuracy:.3f}')
print(f'\nClassification report:\n {classification_report(y_test, y_pred)}')
# Out:
# Model predication accuracy: 0.955
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      0.96      0.98        23
#            2       0.89      1.00      0.94        17
#            3       1.00      1.00      1.00        16
#            4       0.95      0.95      0.95        19
#            5       1.00      1.00      1.00        18
#            6       0.85      0.92      0.88        12
#            7       1.00      1.00      1.00        24
#            8       0.91      0.95      0.93        22
#            9       0.91      0.88      0.89        24
#           10       1.00      1.00      1.00        22
#           11       1.00      0.88      0.93        16
#           12       0.92      0.71      0.80        17
#           13       0.92      1.00      0.96        23
#           14       0.89      1.00      0.94        16
#           15       1.00      1.00      1.00        28
#           16       0.93      1.00      0.96        26
#           17       1.00      0.79      0.88        19
#           18       0.89      0.94      0.91        17
#           19       1.00      1.00      1.00        21
#           20       0.95      1.00      0.98        20
#
#     accuracy                           0.95       420
#    macro avg       0.95      0.95      0.95       420
# weighted avg       0.96      0.95      0.95       420
